# %% [markdown]
# # PID control on TCLab
#
# This notebook and the associated `pidgui.py` allows you to play with a very basic position form discrete PID using either a modelled version or the real Temperature control lab.

# %%
from pidgui import PIDGUI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-debf663331de> in <module>()
# ----> 1 from pidgui import PIDGUI
#
# ~/Dropbox/Git/CBE30338/notebooks/TCLab/pidgui.py in <module>()
#       3 from tclab import Plotter, Historian, TCLab, TCLabModel
#       4 from tclab.gui import actionbutton, labelledvalue, slider
# ----> 5 from tclab.clock import setnow, time
#       6
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tclab.clock'

# %%
# %matplotlib notebook

# %%
interface = PIDGUI()
interface.gui
# Out:
# A Jupyter Widget
# Simulated TCLab
# <img src="data:image/png;base64,..." width="800">
# TCLab Model disconnected successfully.
