# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE30338](https://jckantor.github.io/CBE30338);
# content is available [on Github](https://github.com/jckantor/CBE30338.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [8.1 Zero-Order Hold and Interpolation](https://jckantor.github.io/CBE30338/08.01-Zero-Order-Hold-and-Interpolation.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [9.1 Scheduling State-Task Networks](https://jckantor.github.io/CBE30338/09.01-Scheduling-Multipurpose-Batch-Processes-using-State--Task-Networks.html) ><p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/09.00-Discrete-Events.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://jckantor.github.io/CBE30338/09.00-Discrete-Events.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>

# %% [markdown]
# # 9.0 Discrete Events

# %% [markdown]
# <!--NAVIGATION-->
# < [8.1 Zero-Order Hold and Interpolation](https://jckantor.github.io/CBE30338/08.01-Zero-Order-Hold-and-Interpolation.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [9.1 Scheduling State-Task Networks](https://jckantor.github.io/CBE30338/09.01-Scheduling-Multipurpose-Batch-Processes-using-State--Task-Networks.html) ><p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/09.00-Discrete-Events.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a><p><a href="https://jckantor.github.io/CBE30338/09.00-Discrete-Events.ipynb"> <img align="left" src="https://img.shields.io/badge/Github-Download-blue.svg" alt="Download" title="Download Notebook"></a>
