# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE30338](https://jckantor.github.io/CBE30338);
# content is available [on Github](https://github.com/jckantor/CBE30338.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [6.99 Pyomo Examples](https://jckantor.github.io/CBE30338/06.99-Pyomo-Examples.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [7.1 Simulation and Optimal Control in Pharmacokinetics](https://jckantor.github.io/CBE30338/07.01-Simulation-and-Optimal-Control-in-Pharmacokinetics.html)<p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/07.00-Simulation-and-Optimal-Control.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # 7.0 Simulation and Optimal Control

# %% [markdown]
# ## 7.0.1 Available Solvers
#
# * [ampl.com](https://ampl.com/products/solvers/open-source/)

# %% [markdown]
# <!--NAVIGATION-->
# < [6.99 Pyomo Examples](https://jckantor.github.io/CBE30338/06.99-Pyomo-Examples.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [7.1 Simulation and Optimal Control in Pharmacokinetics](https://jckantor.github.io/CBE30338/07.01-Simulation-and-Optimal-Control-in-Pharmacokinetics.html)<p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/07.00-Simulation-and-Optimal-Control.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>
