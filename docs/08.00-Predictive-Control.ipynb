# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE30338](https://jckantor.github.io/CBE30338);
# content is available [on Github](https://github.com/jckantor/CBE30338.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [7.8 Path Constraints](https://jckantor.github.io/CBE30338/07.08-Path-Constraints.html) | [Contents](toc.html) | [Tag Index](tag_index.html) |

# %% [markdown]
# # 8.0 Predictive Control

# %% [markdown]
# <!--NAVIGATION-->
# < [7.8 Path Constraints](https://jckantor.github.io/CBE30338/07.08-Path-Constraints.html) | [Contents](toc.html) | [Tag Index](tag_index.html) |
