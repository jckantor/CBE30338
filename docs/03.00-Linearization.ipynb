# %% [markdown]
# <!--NOTEBOOK_HEADER-->
# *This notebook contains material from [CBE30338](https://jckantor.github.io/CBE30338);
# content is available [on Github](https://github.com/jckantor/CBE30338.git).*

# %% [markdown]
# <!--NAVIGATION-->
# < [2.8 Model Library](https://jckantor.github.io/CBE30338/02.08-Model-Library.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [3.1 Step Response of a Gravity Drained Tank](https://jckantor.github.io/CBE30338/03.01-Step-Response-of-a-Gravity-Drained-Tank.html)<p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/03.00-Linearization.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # 3.0 Linearization

# %% [markdown]
# <!--NAVIGATION-->
# < [2.8 Model Library](https://jckantor.github.io/CBE30338/02.08-Model-Library.html) | [Contents](toc.html) | [Tag Index](tag_index.html) | [3.1 Step Response of a Gravity Drained Tank](https://jckantor.github.io/CBE30338/03.01-Step-Response-of-a-Gravity-Drained-Tank.html)<p><a href="https://colab.research.google.com/github/jckantor/CBE30338/blob/master/docs/03.00-Linearization.ipynb"> <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>
