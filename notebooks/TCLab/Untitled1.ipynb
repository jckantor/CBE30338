# %%
import tclab
import time


for t in tclab.clock(50, adaptive=True):
    print(t)
    time.sleep(0.02)
# Out:
# 0
# Increase rate
#     step= 1 0.04979844344779849 2.369212914447153
# 1.0
# Increase rate
#     step= 1 0.058822716724534985 2.8430554973365836
# 2.0
# Increase rate
#     step= 1 0.06299616068645264 3.4116665968039004
# 3.0
# Increase rate
#     step= 1 0.07539854888818809 4.09399991616468
# 4.0
# Increase rate
#     step= 1 0.09397362135132425 4.9127998993976165
# 5.0
# Increase rate
#     step= 1 0.12140436095796758 5.89535987927714
# 6.0
# Increase rate
#     step= 1 0.14981899488702766 7.074431855132568
# 7.0
# Increase rate
#     step= 1 0.16497377866471652 8.489318226159082
# 8.0
# Increase rate
#     step= 1 0.1748037263423612 10.187181871390898
# 9.0
# Increase rate
#     step= 1 0.2571530503773829 12.224618245669078
# 10.0
# Increase rate
#     step= 1 0.24902721217586077 14.669541894802892
# 11.0
# Increase rate
#     step= 1 0.30025613358520786 17.60345027376347
# 12.0
# Increase rate
#     step= 1 0.3961496515003091 21.124140328516166
# 13.0
# ...
