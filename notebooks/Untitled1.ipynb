# %% [markdown]
# # Homework One
#
# Jeffrey Kantor
# CBE 30338
# Process Control
#
# We're going to integrate the differential equations
#
# \begin{align*}
# \frac{dV}{dt} & = w_1 + w_2 - w
# \end{align*}

# %%
from pylab import *
# %matplotlib inline
